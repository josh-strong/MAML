# %% [markdown]
# <a href="https://colab.research.google.com/github/JoshStrong/MAML/blob/master/CIFAR_FS_maml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install learn2learn

# %%
import random
import numpy as np

import torch
from torch import nn, optim

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import random

import copy

import learn2learn as l2l
from learn2learn.data.transforms import (NWays,
                                         KShots,
                                         LoadData,
                                         RemapLabels,
                                         ConsecutiveLabels)
from tqdm.notebook import tqdm

# %%
# GPU assigned by google colab for training
torch.cuda.get_device_name(0)
# Out:
# 'Tesla T4'

# %% [markdown]
# ## Acknowledgements
#
# This code makes heavy use of the meta-learning software library learn2learn [1], which makes implementing meta-learning algorithms, such as MAML, much easier. Without learn2learn, implementing MAML requires "hacking" away with PyTorch functionality, which I decided to avoid for the 2nd experimental study to ensure bugless implementation of MAML when applying MAML to the more complex problem of a computer vision related task.
#
#
#
# [1] Sebastien M.R. Arnold, Praateek Mahajan, Debajyoti Datta, Ian Bunner. "learn2learn". https://github.com/learnables/learn2learn, 2019

# %% [markdown]
# ## Construct model to be trained, define helper functions

# %%
# ?l2l.vision.models.ConvBase

# %%
# CNN model to be used in training
# Note how we seperate the head and the body of the network for potential ANIL training

class CifarCNN(torch.nn.Module):
    def __init__(self, output_size=5, hidden_size=32, layers=4):
        super(CifarCNN, self).__init__()
        self.hidden_size = hidden_size

        # Instantiates 4-layer CNN using l2l library
        # 3 rgb channels with 32 hidden size
        # 4 layers
        features = l2l.vision.models.ConvBase(
            output_size=hidden_size,
            hidden=hidden_size,
            channels=3,
            max_pool=False,
            layers=layers,
            max_pool_factor=0.5,
        )
        # Here we call Sequential on previous 4-layer CNN...
        self.features = torch.nn.Sequential(
            features,
            l2l.nn.Lambda(lambda x: x.mean(dim=[2, 3])),
            l2l.nn.Flatten(),
        )
        #... and connect with the 'head' of the model; a fully-connected layer
        self.linear = torch.nn.Linear(self.hidden_size, output_size, bias=True)
        l2l.vision.models.maml_init_(self.linear)

    # Performs forward-pass of the network
    def forward(self, x):
        x = self.features(x)
        x = self.linear(x)
        return x

# %%
model = CifarCNN()
model
# Out:
# CifarCNN(
#   (features): Sequential(
#     (0): ConvBase(
#       (0): ConvBlock(
#         (normalize): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (1): ConvBlock(
#         (normalize): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (2): ConvBlock(
#         (normalize): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (3): ConvBlock(
#         (normalize): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (1): Lambda()
#     (2): Flatten()
#   )
#   (linear): Linear(in_features=32, out_features=5, bias=True)
# )

# %%
# Accuracy function to be used in evaluating models performance

def accuracy(predictions, targets):
    predictions = predictions.argmax(dim=1).view(targets.shape)
    return (predictions == targets).sum().float() / targets.size(0)

# %% [markdown]
# ## Define fast_adapt function for inner loop training

# %%
# inner loop for vision tasks

def fast_adapt(batch, learner, loss, adaptation_steps, shots, ways, device):
    """
    fast_adapt: computes inner loop of MAML for computer vision tasks

    PARAMETERS:
    1. batch = batch of data to train inner loop on 
    2. learner = model to perform inner loop on
    3. loss = loss function to quantify performance
    4. adaptation_steps = number of inner loop gradient steps to be performed
    5. shots = number of data per class
    6. ways = number of classes
    7. device = gpu/cpu (default gpu)
    """
    # seperate data & labels from inputted batch of data
    data, labels = batch
    data, labels = data.to(device), labels.to(device)

    # Separate data into adaptation/evalutation sets with a 50:50 split
    # adaptation data = D^{tr}, evaluation data = D^{test}
    adaptation_indices = np.zeros(data.size(0), dtype=bool) # 50 Falses
    adaptation_indices[np.arange(shots*ways) * 2] = True # Set every even to True
    evaluation_indices = torch.from_numpy(~adaptation_indices) # Opposite of adaptation_indices, make array
    adaptation_indices = torch.from_numpy(adaptation_indices) # Tensor -> array
    adaptation_data, adaptation_labels = data[adaptation_indices], labels[adaptation_indices]
    evaluation_data, evaluation_labels = data[evaluation_indices], labels[evaluation_indices]

    # Perform gradient update of task-specific model copy
    for step in range(adaptation_steps):
        prediction = learner(adaptation_data)
        # Compute loss over all data
        adaptation_error = loss(prediction, adaptation_labels)
        # Average the loss
        adaptation_error /= len(adaptation_data)
        # learner.adapt adjusts model parameters
        learner.adapt(adaptation_error)

    # Comput loss of adapted model to be used for outer-loop update
    # similar to above, except we do not learner.adapt, instead
    # accumulate gradients and perform a meta-update outside of this 
    # function
    predictions = learner(evaluation_data)
    evaluation_error = loss(predictions, evaluation_labels)
    evaluation_error /= len(evaluation_data)
    evaluation_accuracy = accuracy(predictions, evaluation_labels)
    return evaluation_error, evaluation_accuracy

# %% [markdown]
# ## Use learn2learn library for easy access to CIFAR-FS dataset

# %%
# Use l2l framework to get CIFAR-FS data
# in a form useful for few-shot meta-learning
# use 2*shots in generating training samples
# since we need D^{tr} and D^{test}

shots=5
ways=5
tasksets = l2l.vision.benchmarks.get_tasksets(
        name='cifarfs',
        train_samples=2*shots,
        train_ways=ways,
        test_samples=2*shots,
        test_ways=ways,
        root='~/data',
    )

# %% [markdown]
# ## Define CIFARFS_MAML function
#
# CIFARS_MAML implements the main portion of the MAML algorithm for computer-vision related tasks.

# %%
def CIFARFS_MAML(ways=5, shots=5, meta_lr=0.003, inner_lr=0.5, meta_batch_size=32, adaptation_steps=1, num_iterations=10000):
    # Instantiate cifarCNN model, send to gpu
    model = CifarCNN()
    model.to('cuda')
    maml = l2l.algorithms.MAML(model, lr=inner_lr, first_order=False)

    # Use Adam optimiser and cross entropy loss
    opt = optim.Adam(maml.parameters(), meta_lr)
    loss = nn.CrossEntropyLoss(reduction='mean')

    # Meta-learning
    # Outer-loop
    # num_iterations = number of outer-loop updates
    for iteration in tqdm(range(num_iterations)):
        opt.zero_grad()
        meta_valid_error = 0.0
        meta_valid_accuracy = 0.0

        # For each sampled task T_i 
        for task in range(meta_batch_size):
            # Clone the meta-parameters to perform task-specific adaptation
            learner = maml.clone()
            batch = tasksets.train.sample()
            # Perform the inner loop with this batch of data from sampled task
            evaluation_error, evaluation_accuracy = fast_adapt(batch,
                                                               learner,
                                                               loss,
                                                               adaptation_steps,
                                                               shots,
                                                               ways,
                                                               'cuda')
            # Do a backwards pass to compute & accumulate gradients
            evaluation_error.backward()

            # Compute meta-validation loss
            learner = maml.clone()
            batch = tasksets.validation.sample()
            evaluation_error, evaluation_accuracy = fast_adapt(batch,
                                                               learner,
                                                               loss,
                                                               adaptation_steps,
                                                               shots,
                                                               ways,
                                                               'cuda')
            meta_valid_error += evaluation_error.item()
            meta_valid_accuracy += evaluation_accuracy.item()

        avg_meta_valid_err = meta_valid_error/meta_batch_size
        avg_meta_valid_acc = meta_valid_accuracy / meta_batch_size
        if iteration % 50 == 0:
          print('\n')
          print('Iteration', iteration)
          print('Average Meta Valid Error', avg_meta_valid_err)
          print('Average Meta Valid Accuracy', avg_meta_valid_acc)

        # Average the accumulated gradients from all tasks and optimize
        for p in maml.parameters():
            p.grad.data.mul_(1.0 / meta_batch_size)
        opt.step()

    return model

# %%
model = CIFARFS_MAML()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:385: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if param.grad is not None:
# Iteration 0
# Average Meta Valid Error 0.06647501117549837
# Average Meta Valid Accuracy 0.19999998807907104
#
#
# Iteration 50
# Average Meta Valid Error 0.06198663148097694
# Average Meta Valid Accuracy 0.2687499930616468
#
#
# Iteration 100
# Average Meta Valid Error 0.06170825252775103
# Average Meta Valid Accuracy 0.28749999264255166
#
#
# Iteration 150
# Average Meta Valid Error 0.06118645064998418
# Average Meta Valid Accuracy 0.29874999169260263
#
#
# Iteration 200
# Average Meta Valid Error 0.05942488776054233
# Average Meta Valid Accuracy 0.34874999057501554
#
#
# Iteration 250
# Average Meta Valid Error 0.06233933346811682
# Average Meta Valid Accuracy 0.2974999900907278
#
#
# Iteration 300
# Average Meta Valid Error 0.06011559732723981
# Average Meta Valid Accuracy 0.3387499905657023
#
#
# Iteration 350
# Average Meta Valid Error 0.05991319171153009
# Average Meta Valid Accuracy 0.347499989438802
#
#
# Iteration 400
# Average Meta Valid Error 0.06033550656866282
# Average Meta Valid Accuracy 0.3399999898392707
#
#
# Iteration 450
# Average Meta Valid Error 0.060527289868332446
# Average Meta Valid Accuracy 0.3349999899510294
#
#
# Iteration 500
# Average Meta Valid Error 0.057721563847735524
# Average Meta Valid Accuracy 0.3762499901931733
#
#
# Iteration 550
# Average Meta Valid Error 0.05696353001985699
# Average Meta Valid Accuracy 0.38624998996965587
#
#
# Iteration 600
# Average Meta Valid Error 0.05504269676748663
# Average Meta Valid Accuracy 0.40999999083578587
#
#
# Iteration 650
# Average Meta Valid Error 0.05500340519938618
# Average Meta Valid Accuracy 0.41374998912215233
#
#
# Iteration 700
# Average Meta Valid Error 0.0564552036812529
# Average Meta Valid Accuracy 0.402499983785674
#
#
# Iteration 750
# Average Meta Valid Error 0.055750458617694676
# Average Meta Valid Accuracy 0.4362499909475446
#
#
# Iteration 800
# Average Meta Valid Error 0.05594336416106671
# Average Meta Valid Accuracy 0.39874998945742846
#
#
# Iteration 850
# Average Meta Valid Error 0.05372615728992969
# Average Meta Valid Accuracy 0.4337499891407788
#
#
# Iteration 900
# Average Meta Valid Error 0.054593393579125404
# Average Meta Valid Accuracy 0.4087499864399433
#
#
# Iteration 950
# Average Meta Valid Error 0.05523716693278402
# Average Meta Valid Accuracy 0.41624998953193426
#
#
# Iteration 1000
# Average Meta Valid Error 0.055508247460238636
# Average Meta Valid Accuracy 0.4087499906308949
#
#
# Iteration 1050
# Average Meta Valid Error 0.0543765613110736
# Average Meta Valid Accuracy 0.44124998757615685
#
#
# Iteration 1100
# Average Meta Valid Error 0.0562188004842028
# Average Meta Valid Accuracy 0.4162499909289181
#
#
# Iteration 1150
# Average Meta Valid Error 0.052977125451434404
# Average Meta Valid Accuracy 0.46374998707324266
#
#
# Iteration 1200
# Average Meta Valid Error 0.052233904018066823
# Average Meta Valid Accuracy 0.45749998837709427
#
#
# Iteration 1250
# Average Meta Valid Error 0.054343461990356445
# Average Meta Valid Accuracy 0.446249988861382
#
#
# Iteration 1300
# Average Meta Valid Error 0.05271352187264711
# Average Meta Valid Accuracy 0.4624999859370291
#
#
# Iteration 1350
# Average Meta Valid Error 0.04991939361207187
# Average Meta Valid Accuracy 0.4549999888986349
#
#
# Iteration 1400
# Average Meta Valid Error 0.053666044608689845
# Average Meta Valid Accuracy 0.4499999866820872
#
#
# Iteration 1450
# Average Meta Valid Error 0.0510841712821275
# Average Meta Valid Accuracy 0.47999998996965587
#
#
# Iteration 1500
# Average Meta Valid Error 0.051918490091338754
# Average Meta Valid Accuracy 0.4899999899789691
#
#
# Iteration 1550
# Average Meta Valid Error 0.05037115572486073
# Average Meta Valid Accuracy 0.48124998435378075
#
#
# Iteration 1600
# Average Meta Valid Error 0.04858390078879893
# Average Meta Valid Accuracy 0.5049999873153865
#
#
# Iteration 1650
# Average Meta Valid Error 0.05095182219520211
# Average Meta Valid Accuracy 0.4837499875575304
#
#
# Iteration 1700
# Average Meta Valid Error 0.05014418298378587
# Average Meta Valid Accuracy 0.5037499843165278
#
#
# Iteration 1750
# Average Meta Valid Error 0.052173397154547274
# Average Meta Valid Accuracy 0.4474999872036278
#
#
# Iteration 1800
# Average Meta Valid Error 0.050777173368260264
# Average Meta Valid Accuracy 0.5024999883025885
#
#
# Iteration 1850
# Average Meta Valid Error 0.05012382159475237
# Average Meta Valid Accuracy 0.4837499875575304
#
#
# Iteration 1900
# Average Meta Valid Error 0.04961543437093496
# Average Meta Valid Accuracy 0.4999999888241291
#
#
# Iteration 1950
# Average Meta Valid Error 0.049761858652345836
# Average Meta Valid Accuracy 0.4912499883212149
#
#
# Iteration 2000
# Average Meta Valid Error 0.049693255918100476
# Average Meta Valid Accuracy 0.48499998869374394
#
#
# Iteration 2050
# Average Meta Valid Error 0.050856865011155605
# Average Meta Valid Accuracy 0.4899999890476465
#
#
# Iteration 2100
# Average Meta Valid Error 0.05047817761078477
# Average Meta Valid Accuracy 0.46874998742714524
#
#
# Iteration 2150
# Average Meta Valid Error 0.04617562278872356
# Average Meta Valid Accuracy 0.5374999898485839
#
#
# Iteration 2200
# Average Meta Valid Error 0.04844916402362287
# Average Meta Valid Accuracy 0.49499998707324266
#
#
# Iteration 2250
# Average Meta Valid Error 0.048753086128272116
# Average Meta Valid Accuracy 0.48249998688697815
#
#
# Iteration 2300
# Average Meta Valid Error 0.047720147063955665
# Average Meta Valid Accuracy 0.5074999807402492
#
#
# Iteration 2350
# Average Meta Valid Error 0.04951968643581495
# Average Meta Valid Accuracy 0.5112499864771962
#
#
# Iteration 2400
# Average Meta Valid Error 0.04911745467688888
# Average Meta Valid Accuracy 0.49999998649582267
#
#
# Iteration 2450
# Average Meta Valid Error 0.04852453782223165
# Average Meta Valid Accuracy 0.5062499879859388
#
#
# Iteration 2500
# Average Meta Valid Error 0.046238255221396685
# Average Meta Valid Accuracy 0.5499999858438969
#
#
# Iteration 2550
# Average Meta Valid Error 0.04825756908394396
# Average Meta Valid Accuracy 0.5049999887123704
#
#
# Iteration 2600
# Average Meta Valid Error 0.0488512022420764
# Average Meta Valid Accuracy 0.48999998392537236
#
#
# Iteration 2650
# Average Meta Valid Error 0.04953045572619885
# Average Meta Valid Accuracy 0.4987499890848994
#
#
# Iteration 2700
# Average Meta Valid Error 0.0440544193261303
# Average Meta Valid Accuracy 0.5649999883025885
#
#
# Iteration 2750
# Average Meta Valid Error 0.047982640273403376
# Average Meta Valid Accuracy 0.5074999881908298
#
#
# Iteration 2800
# Average Meta Valid Error 0.046414468553848565
# Average Meta Valid Accuracy 0.5362499868497252
#
#
# Iteration 2850
# Average Meta Valid Error 0.04644558485597372
# Average Meta Valid Accuracy 0.5137499854899943
#
#
# Iteration 2900
# Average Meta Valid Error 0.050913001934532076
# Average Meta Valid Accuracy 0.4999999860301614
#
#
# Iteration 2950
# Average Meta Valid Error 0.04625596373807639
# Average Meta Valid Accuracy 0.5424999855458736
#
#
# Iteration 3000
# Average Meta Valid Error 0.048226295970380306
# Average Meta Valid Accuracy 0.5212499862536788
#
#
# Iteration 3050
# Average Meta Valid Error 0.04873975377995521
# Average Meta Valid Accuracy 0.5124999852851033
#
#
# Iteration 3100
# Average Meta Valid Error 0.047108076920267195
# Average Meta Valid Accuracy 0.5512499874457717
#
#
# Iteration 3150
# Average Meta Valid Error 0.046155751042533666
# Average Meta Valid Accuracy 0.5337499841116369
#
#
# Iteration 3200
# Average Meta Valid Error 0.04377187497448176
# Average Meta Valid Accuracy 0.5749999843537807
#
#
# Iteration 3250
# Average Meta Valid Error 0.04678020242135972
# Average Meta Valid Accuracy 0.5037499850150198
#
#
# Iteration 3300
# Average Meta Valid Error 0.046751354122534394
# Average Meta Valid Accuracy 0.5112499836832285
#
#
# Iteration 3350
# Average Meta Valid Error 0.047268144437111914
# Average Meta Valid Accuracy 0.5149999842979014
#
#
# Iteration 3400
# Average Meta Valid Error 0.04521765391109511
# Average Meta Valid Accuracy 0.5412499853409827
#
#
# Iteration 3450
# Average Meta Valid Error 0.049409833271056414
# Average Meta Valid Accuracy 0.4737499877810478
#
#
# Iteration 3500
# Average Meta Valid Error 0.04882758780149743
# Average Meta Valid Accuracy 0.4949999861419201
#
#
# Iteration 3550
# Average Meta Valid Error 0.044782094191759825
# Average Meta Valid Accuracy 0.548749984242022
#
#
# Iteration 3600
# Average Meta Valid Error 0.04516350623453036
# Average Meta Valid Accuracy 0.5524999853223562
#
#
# Iteration 3650
# Average Meta Valid Error 0.04775387130212039
# Average Meta Valid Accuracy 0.49249998992308974
#
#
# Iteration 3700
# Average Meta Valid Error 0.04661850607953966
# Average Meta Valid Accuracy 0.512499988079071
#
#
# Iteration 3750
# Average Meta Valid Error 0.04519434424582869
# Average Meta Valid Accuracy 0.5462499912828207
#
#
# Iteration 3800
# Average Meta Valid Error 0.04682058945763856
# Average Meta Valid Accuracy 0.541249985806644
#
#
# Iteration 3850
# Average Meta Valid Error 0.04886965820332989
# Average Meta Valid Accuracy 0.5024999887682498
#
#
# Iteration 3900
# Average Meta Valid Error 0.04694171220762655
# Average Meta Valid Accuracy 0.5287499893456697
#
#
# Iteration 3950
# Average Meta Valid Error 0.04702266398817301
# Average Meta Valid Accuracy 0.5099999867379665
#
#
# Iteration 4000
# Average Meta Valid Error 0.04607185069471598
# Average Meta Valid Accuracy 0.5299999853596091
#
#
# Iteration 4050
# Average Meta Valid Error 0.043523570406250656
# Average Meta Valid Accuracy 0.579999984242022
#
#
# Iteration 4100
# Average Meta Valid Error 0.0490572223206982
# Average Meta Valid Accuracy 0.526249987538904
#
#
# Iteration 4150
# Average Meta Valid Error 0.04663680342491716
# Average Meta Valid Accuracy 0.519999991171062
#
#
# Iteration 4200
# Average Meta Valid Error 0.045942321652546525
# Average Meta Valid Accuracy 0.5424999902024865
#
#
# Iteration 4250
# Average Meta Valid Error 0.047091758460737765
# Average Meta Valid Accuracy 0.5212499871850014
#
#
# Iteration 4300
# Average Meta Valid Error 0.043100156530272216
# Average Meta Valid Accuracy 0.5687499903142452
#
#
# Iteration 4350
# Average Meta Valid Error 0.043400254915468395
# Average Meta Valid Accuracy 0.5674999859184027
#
#
# Iteration 4400
# Average Meta Valid Error 0.047103181947022676
# Average Meta Valid Accuracy 0.5374999865889549
#
#
# Iteration 4450
# Average Meta Valid Error 0.04528987826779485
# Average Meta Valid Accuracy 0.5337499864399433
#
#
# Iteration 4500
# Average Meta Valid Error 0.04429668973898515
# Average Meta Valid Accuracy 0.5612499872222543
#
#
# Iteration 4550
# Average Meta Valid Error 0.0436829422833398
# Average Meta Valid Accuracy 0.5637499876320362
#
#
# Iteration 4600
# Average Meta Valid Error 0.04520797618897632
# Average Meta Valid Accuracy 0.5449999878183007
#
#
# Iteration 4650
# Average Meta Valid Error 0.0461238072020933
# Average Meta Valid Accuracy 0.5574999852105975
#
#
# Iteration 4700
# Average Meta Valid Error 0.04470253619365394
# Average Meta Valid Accuracy 0.5562499864026904
#
#
# Iteration 4750
# Average Meta Valid Error 0.04433562414487824
# Average Meta Valid Accuracy 0.5587499849498272
#
#
# Iteration 4800
# Average Meta Valid Error 0.044496387999970466
# Average Meta Valid Accuracy 0.5687499903142452
#
#
# Iteration 4850
# Average Meta Valid Error 0.0436825206852518
# Average Meta Valid Accuracy 0.5612499853596091
#
#
# Iteration 4900
# Average Meta Valid Error 0.04589393734931946
# Average Meta Valid Accuracy 0.5299999872222543
#
#
# Iteration 4950
# Average Meta Valid Error 0.04295335948700085
# Average Meta Valid Accuracy 0.5787499835714698
#
#
# Iteration 5000
# Average Meta Valid Error 0.04724596504820511
# Average Meta Valid Accuracy 0.5262499842792749
#
#
# Iteration 5050
# Average Meta Valid Error 0.04267705004895106
# Average Meta Valid Accuracy 0.5837499871850014
#
#
# Iteration 5100
# Average Meta Valid Error 0.045995974040124565
# Average Meta Valid Accuracy 0.5387499872595072
#
#
# Iteration 5150
# Average Meta Valid Error 0.04581009951652959
# Average Meta Valid Accuracy 0.5624999850988388
#
#
# Iteration 5200
# Average Meta Valid Error 0.044058664061594754
# Average Meta Valid Accuracy 0.5587499816901982
#
#
# Iteration 5250
# Average Meta Valid Error 0.042576236359309405
# Average Meta Valid Accuracy 0.5724999867379665
#
#
# Iteration 5300
# Average Meta Valid Error 0.04393555235583335
# Average Meta Valid Accuracy 0.5612499872222543
#
#
# Iteration 5350
# Average Meta Valid Error 0.04527974803932011
# Average Meta Valid Accuracy 0.5449999840930104
#
#
# Iteration 5400
# Average Meta Valid Error 0.04361297737341374
# Average Meta Valid Accuracy 0.5599999856203794
#
#
# Iteration 5450
# Average Meta Valid Error 0.04343045147834346
# Average Meta Valid Accuracy 0.564999982714653
#
#
# Iteration 5500
# Average Meta Valid Error 0.04528125049546361
# Average Meta Valid Accuracy 0.5287499846890569
#
#
# Iteration 5550
# Average Meta Valid Error 0.043080521922092885
# Average Meta Valid Accuracy 0.5724999881349504
#
#
# Iteration 5600
# Average Meta Valid Error 0.042979016609024256
# Average Meta Valid Accuracy 0.5937499850988388
#
#
# Iteration 5650
# Average Meta Valid Error 0.04500275861937553
# Average Meta Valid Accuracy 0.5499999886378646
#
#
# Iteration 5700
# Average Meta Valid Error 0.04482393671059981
# Average Meta Valid Accuracy 0.5537499859929085
#
#
# Iteration 5750
# Average Meta Valid Error 0.04287099320208654
# Average Meta Valid Accuracy 0.5637499885633588
#
#
# Iteration 5800
# Average Meta Valid Error 0.045908905449323356
# Average Meta Valid Accuracy 0.5312499888241291
#
#
# Iteration 5850
# Average Meta Valid Error 0.04351536475587636
# Average Meta Valid Accuracy 0.5649999845772982
#
#
# Iteration 5900
# Average Meta Valid Error 0.045708575926255435
# Average Meta Valid Accuracy 0.5424999855458736
#
#
# Iteration 5950
# Average Meta Valid Error 0.04466483503347263
# Average Meta Valid Accuracy 0.5474999928846955
#
#
# Iteration 6000
# Average Meta Valid Error 0.04543652426218614
# Average Meta Valid Accuracy 0.5624999878928065
#
#
# Iteration 6050
# Average Meta Valid Error 0.044802889227867126
# Average Meta Valid Accuracy 0.5674999849870801
#
#
# Iteration 6100
# Average Meta Valid Error 0.04267699929187074
# Average Meta Valid Accuracy 0.5462499856948853
#
#
# Iteration 6150
# Average Meta Valid Error 0.043846045969985425
# Average Meta Valid Accuracy 0.5462499866262078
#
#
# Iteration 6200
# Average Meta Valid Error 0.04253759467974305
# Average Meta Valid Accuracy 0.5687499837949872
#
#
# Iteration 6250
# Average Meta Valid Error 0.04700270766625181
# Average Meta Valid Accuracy 0.523749983869493
#
#
# Iteration 6300
# Average Meta Valid Error 0.03664265759289265
# Average Meta Valid Accuracy 0.6524999821558595
#
#
# Iteration 6350
# Average Meta Valid Error 0.04529892618302256
# Average Meta Valid Accuracy 0.5349999875761569
#
#
# Iteration 6400
# Average Meta Valid Error 0.04418653715401888
# Average Meta Valid Accuracy 0.5549999889917672
#
#
# Iteration 6450
# Average Meta Valid Error 0.041255534859374166
# Average Meta Valid Accuracy 0.5774999856948853
#
#
# Iteration 6500
# Average Meta Valid Error 0.04302105895476416
# Average Meta Valid Accuracy 0.559999986551702
#
#
# Iteration 6550
# Average Meta Valid Error 0.04330518614733592
# Average Meta Valid Accuracy 0.5524999815970659
#
#
# Iteration 6600
# Average Meta Valid Error 0.040165569982491434
# Average Meta Valid Accuracy 0.617499980609864
#
#
# Iteration 6650
# Average Meta Valid Error 0.043690180231351405
# Average Meta Valid Accuracy 0.567499989643693
#
#
# Iteration 6700
# Average Meta Valid Error 0.04236258793389425
# Average Meta Valid Accuracy 0.5837499867193401
#
#
# Iteration 6750
# Average Meta Valid Error 0.04502987471641973
# Average Meta Valid Accuracy 0.5787499849684536
#
#
# Iteration 6800
# Average Meta Valid Error 0.042358596343547106
# Average Meta Valid Accuracy 0.5837499871850014
#
#
# Iteration 6850
# Average Meta Valid Error 0.0447239056811668
# Average Meta Valid Accuracy 0.5824999855831265
#
#
# Iteration 6900
# Average Meta Valid Error 0.04361988080199808
# Average Meta Valid Accuracy 0.571249988861382
#
#
# Iteration 6950
# Average Meta Valid Error 0.044138223107438534
# Average Meta Valid Accuracy 0.5512499902397394
#
#
# Iteration 7000
# Average Meta Valid Error 0.044135125004686415
# Average Meta Valid Accuracy 0.5549999848008156
#
#
# Iteration 7050
# Average Meta Valid Error 0.04209764301776886
# Average Meta Valid Accuracy 0.5787499854341149
#
#
# Iteration 7100
# Average Meta Valid Error 0.044064694142434746
# Average Meta Valid Accuracy 0.5424999874085188
#
#
# Iteration 7150
# Average Meta Valid Error 0.043536674813367426
# Average Meta Valid Accuracy 0.5587499849498272
#
#
# Iteration 7200
# Average Meta Valid Error 0.04382967733545229
# Average Meta Valid Accuracy 0.5624999855645001
#
#
# Iteration 7250
# Average Meta Valid Error 0.04274452448589727
# Average Meta Valid Accuracy 0.5687499865889549
#
#
# Iteration 7300
# Average Meta Valid Error 0.04445266613038257
# Average Meta Valid Accuracy 0.5562499836087227
#
#
# Iteration 7350
# Average Meta Valid Error 0.0468090440845117
# Average Meta Valid Accuracy 0.528749986551702
#
#
# Iteration 7400
# Average Meta Valid Error 0.0419448409229517
# Average Meta Valid Accuracy 0.5787499826401472
#
#
# Iteration 7450
# Average Meta Valid Error 0.04396524711046368
# Average Meta Valid Accuracy 0.568749981932342
#
#
# Iteration 7500
# Average Meta Valid Error 0.044176742318086326
# Average Meta Valid Accuracy 0.559999986551702
#
#
# Iteration 7550
# Average Meta Valid Error 0.041701626032590866
# Average Meta Valid Accuracy 0.574999988079071
#
#
# Iteration 7600
# Average Meta Valid Error 0.04269569035386667
# Average Meta Valid Accuracy 0.568749981932342
#
#
# Iteration 7650
# Average Meta Valid Error 0.04374980152351782
# Average Meta Valid Accuracy 0.567499983124435
#
#
# Iteration 7700
# Average Meta Valid Error 0.0450833531212993
# Average Meta Valid Accuracy 0.5574999861419201
#
#
# Iteration 7750
# Average Meta Valid Error 0.04242754413280636
# Average Meta Valid Accuracy 0.5874999845400453
#
#
# Iteration 7800
# Average Meta Valid Error 0.042244056588970125
# Average Meta Valid Accuracy 0.5724999830126762
#
#
# Iteration 7850
# Average Meta Valid Error 0.0439729958306998
# Average Meta Valid Accuracy 0.549999987706542
#
#
# Iteration 7900
# Average Meta Valid Error 0.039931114530190825
# Average Meta Valid Accuracy 0.6199999824166298
#
#
# Iteration 7950
# Average Meta Valid Error 0.04463005549041554
# Average Meta Valid Accuracy 0.5687499810010195
#
#
# Iteration 8000
# Average Meta Valid Error 0.04097184824058786
# Average Meta Valid Accuracy 0.5687499856576324
#
#
# Iteration 8050
# Average Meta Valid Error 0.0450485396431759
# Average Meta Valid Accuracy 0.5599999874830246
#
#
# Iteration 8100
# Average Meta Valid Error 0.04482604993972927
# Average Meta Valid Accuracy 0.5649999883025885
#
#
# Iteration 8150
# Average Meta Valid Error 0.046978631522506475
# Average Meta Valid Accuracy 0.5074999849312007
#
#
# Iteration 8200
# Average Meta Valid Error 0.04481866990681738
# Average Meta Valid Accuracy 0.536249989643693
#
#
# Iteration 8250
# Average Meta Valid Error 0.04054077697219327
# Average Meta Valid Accuracy 0.581249981187284
#
#
# Iteration 8300
# Average Meta Valid Error 0.04192884574877098
# Average Meta Valid Accuracy 0.5824999827891588
#
#
# Iteration 8350
# Average Meta Valid Error 0.04451413289643824
# Average Meta Valid Accuracy 0.5737499874085188
#
#
# Iteration 8400
# Average Meta Valid Error 0.0448171267635189
# Average Meta Valid Accuracy 0.5674999877810478
#
#
# Iteration 8450
# Average Meta Valid Error 0.04436014883685857
# Average Meta Valid Accuracy 0.5412499867379665
#
#
# Iteration 8500
# Average Meta Valid Error 0.042761000455357134
# Average Meta Valid Accuracy 0.5699999900534749
#
#
# Iteration 8550
# Average Meta Valid Error 0.04424505622591823
# Average Meta Valid Accuracy 0.5574999852105975
#
#
# Iteration 8600
# Average Meta Valid Error 0.04281762783648446
# Average Meta Valid Accuracy 0.5949999843724072
#
#
# Iteration 8650
# Average Meta Valid Error 0.041725715214852244
# Average Meta Valid Accuracy 0.5812499835155904
#
#
# Iteration 8700
# Average Meta Valid Error 0.04502940707607195
# Average Meta Valid Accuracy 0.5362499877810478
#
#
# Iteration 8750
# Average Meta Valid Error 0.04378840088611469
# Average Meta Valid Accuracy 0.5599999893456697
#
#
# Iteration 8800
# Average Meta Valid Error 0.03995417896658182
# Average Meta Valid Accuracy 0.5949999857693911
#
#
# Iteration 8850
# Average Meta Valid Error 0.042813402717001736
# Average Meta Valid Accuracy 0.5912499856203794
#
#
# Iteration 8900
# Average Meta Valid Error 0.045163344766478986
# Average Meta Valid Accuracy 0.5337499873712659
#
#
# Iteration 8950
# Average Meta Valid Error 0.041439949127379805
# Average Meta Valid Accuracy 0.6049999836832285
#
#
# Iteration 9000
# Average Meta Valid Error 0.045553956064395607
# Average Meta Valid Accuracy 0.5337499845772982
#
#
# Iteration 9050
# Average Meta Valid Error 0.040609686460811645
# Average Meta Valid Accuracy 0.6012499835342169
#
#
# Iteration 9100
# Average Meta Valid Error 0.042234662105329335
# Average Meta Valid Accuracy 0.5699999844655395
#
#
# Iteration 9150
# Average Meta Valid Error 0.043403307849075645
# Average Meta Valid Accuracy 0.5712499851360917
#
#
# Iteration 9200
# Average Meta Valid Error 0.04452527826651931
# Average Meta Valid Accuracy 0.5662499889731407
#
#
# Iteration 9250
# Average Meta Valid Error 0.04412916791625321
# Average Meta Valid Accuracy 0.5549999857321382
#
#
# Iteration 9300
# Average Meta Valid Error 0.04248434747569263
# Average Meta Valid Accuracy 0.576249985024333
#
#
# Iteration 9350
# Average Meta Valid Error 0.0437461722176522
# Average Meta Valid Accuracy 0.5712499874643981
#
#
# Iteration 9400
# Average Meta Valid Error 0.04215057130204514
# Average Meta Valid Accuracy 0.5724999862723053
#
#
# Iteration 9450
# Average Meta Valid Error 0.042885160248260945
# Average Meta Valid Accuracy 0.553749986924231
#
#
# Iteration 9500
# Average Meta Valid Error 0.04205874784383923
# Average Meta Valid Accuracy 0.5899999886751175
#
#
# Iteration 9550
# Average Meta Valid Error 0.043862654303666204
# Average Meta Valid Accuracy 0.5399999860674143
#
#
# Iteration 9600
# Average Meta Valid Error 0.04291049751918763
# Average Meta Valid Accuracy 0.5537499887868762
#
#
# Iteration 9650
# Average Meta Valid Error 0.043144769384525716
# Average Meta Valid Accuracy 0.5662499815225601
#
#
# Iteration 9700
# Average Meta Valid Error 0.03874670248478651
# Average Meta Valid Accuracy 0.6099999835714698
#
#
# Iteration 9750
# Average Meta Valid Error 0.039185583882499486
# Average Meta Valid Accuracy 0.6099999882280827
#
#
# Iteration 9800
# Average Meta Valid Error 0.043026879720855504
# Average Meta Valid Accuracy 0.5687499884516001
#
#
# Iteration 9850
# Average Meta Valid Error 0.042876973981037736
# Average Meta Valid Accuracy 0.5637499848380685
#
#
# Iteration 9900
# Average Meta Valid Error 0.04054588847793639
# Average Meta Valid Accuracy 0.6012499835342169
#
#
# Iteration 9950
# Average Meta Valid Error 0.0435105393989943
# Average Meta Valid Accuracy 0.5624999888241291

# %%
# Save the meta-parameters to a file
# Need to clip 'module.' from parameter keys in order to reload the model first
maml_dict = model.state_dict()
prefix = 'module.'
n_clip = len(prefix)
adapted_dict = {k[n_clip:]: v for k, v in maml_dict.items()
                if k.startswith(prefix)}

PATH = "/content/model_CISFAR"
torch.save(adapted_dict, PATH)

# %%
# Load MAML saved parameters
PATH = "/content/model_CISFAR"
saved_model = CifarCNN()
saved_model.load_state_dict(torch.load(PATH), strict=False)
saved_model.to('cuda')
# Out:
# CifarCNN(
#   (features): Sequential(
#     (0): ConvBase(
#       (0): ConvBlock(
#         (normalize): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (1): ConvBlock(
#         (normalize): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (2): ConvBlock(
#         (normalize): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (3): ConvBlock(
#         (normalize): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU()
#         (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#     )
#     (1): Lambda()
#     (2): Flatten()
#   )
#   (linear): Linear(in_features=32, out_features=5, bias=True)
# )

# %% [markdown]
# ## Perform fine-tuning, evaluate performance

# %%
meta_test_error = 0.0
meta_test_accuracy = 0.0
meta_batch_size = 32
meta_lr=0.003
inner_lr=0.5
adaptation_steps=1

opt = optim.Adam(maml.parameters(), meta_lr)
loss = nn.CrossEntropyLoss(reduction='mean')


maml = l2l.algorithms.MAML(model, lr=inner_lr, first_order=False)
for task in range(meta_batch_size):
  # Compute meta-testing loss
  learner = maml.clone()
  batch = tasksets.test.sample()
  evaluation_error, evaluation_accuracy = fast_adapt(batch,
                                                    learner,
                                                    loss,
                                                    adaptation_steps,
                                                    shots,
                                                    ways,
                                                    'cuda')
  meta_test_error += evaluation_error.item()
  meta_test_accuracy += evaluation_accuracy.item()
  print('Avg Meta Test Accuracy', round(meta_test_accuracy / meta_batch_size,2)*100,'%')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py:385: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the gradient for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations.
#   if param.grad is not None:
# Avg Meta Test Accuracy 2.0 %
# Avg Meta Test Accuracy 4.0 %
# Avg Meta Test Accuracy 6.0 %
# Avg Meta Test Accuracy 9.0 %
# Avg Meta Test Accuracy 11.0 %
# Avg Meta Test Accuracy 13.0 %
# Avg Meta Test Accuracy 15.0 %
# Avg Meta Test Accuracy 17.0 %
# Avg Meta Test Accuracy 19.0 %
# Avg Meta Test Accuracy 21.0 %
# Avg Meta Test Accuracy 23.0 %
# Avg Meta Test Accuracy 25.0 %
# Avg Meta Test Accuracy 28.000000000000004 %
# Avg Meta Test Accuracy 30.0 %
# Avg Meta Test Accuracy 32.0 %
# Avg Meta Test Accuracy 34.0 %
# Avg Meta Test Accuracy 36.0 %
# Avg Meta Test Accuracy 38.0 %
# Avg Meta Test Accuracy 39.0 %
# Avg Meta Test Accuracy 41.0 %
# Avg Meta Test Accuracy 43.0 %
# Avg Meta Test Accuracy 44.0 %
# Avg Meta Test Accuracy 46.0 %
# Avg Meta Test Accuracy 47.0 %
# Avg Meta Test Accuracy 49.0 %
# Avg Meta Test Accuracy 51.0 %
# Avg Meta Test Accuracy 54.0 %
# Avg Meta Test Accuracy 56.00000000000001 %
# Avg Meta Test Accuracy 57.99999999999999 %
# Avg Meta Test Accuracy 60.0 %
# Avg Meta Test Accuracy 62.0 %
# Avg Meta Test Accuracy 64.0 %
